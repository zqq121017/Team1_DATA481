# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Configuration
log_file = 'training_logs/5_kfold_tfpower_trial_score_20260330_210910.csv'
METRIC_COLS = ['Train_MSE', 'Val_MSE', 'Val_RMSE', 'Val_MAE', 'Val_R2']

if not os.path.exists(log_file):
    print(f"Error: File {log_file} not found.")
else:
    # Improved Loading: Skip metadata by searching for the header row
    # If your file consistently starts data on line 53, skiprows=52 is fine,
    # but using comment='#' helps ignore configuration lines if they are prefixed.
    df_raw = pd.read_csv(log_file, skiprows=61, comment='#')

    # Clean data: Remove rows that aren't epoch records (e.g., summary stats)
    df = df_raw[pd.to_numeric(df_raw['Fold'], errors='coerce').notnull()].copy()
    
    # Cast types correctly
    df['Fold'] = df['Fold'].astype(int)
    df['Epoch'] = df['Epoch'].astype(int)
    for col in METRIC_COLS:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    print(f"Successfully loaded {len(df)} records.")
    print(f"Folds detected: {df['Fold'].unique()}")
    print(df.head())
# Out:
# Successfully loaded 500 records.
# Folds detected: [1 2 3 4 5]
#    Epoch  Train_MSE  Val_MSE  Val_RMSE  Val_MAE  Val_R2  Fold  Total_Params  \
# 0      1    85.0099  56.3889    7.5093   6.3325 -0.0335     1      571457.0
# 1      2    46.8434  47.0831    6.8617   5.7474  0.1371     1      571457.0
# 2      3    39.1387  39.3797    6.2753   5.2669  0.2783     1      571457.0
# 3      4    31.4687  29.4804    5.4296   4.3283  0.4597     1      571457.0
# 4      5    26.5657  28.2674    5.3167   4.3364  0.4819     1      571457.0
#
#    Trainable_Params
# 0          571457.0
# 1          571457.0
# 2          571457.0
# 3          571457.0
# 4          571457.0

# %%
folds = sorted(df['Fold'].unique())
fig, axes = plt.subplots(len(folds), 1, figsize=(12, 4 * len(folds)), sharex=True)

# Ensure axes is iterable even if there is only 1 fold
if len(folds) == 1:
    axes = [axes]

for i, fold in enumerate(folds):
    fold_df = df[df['Fold'] == fold]
    ax = axes[i]
    
    ax.plot(fold_df['Epoch'], fold_df['Train_MSE'], label='Train MSE', color='royalblue', alpha=0.6)
    ax.plot(fold_df['Epoch'], fold_df['Val_MSE'], label='Val MSE', color='crimson', linewidth=2)
    
    # Identify the best epoch for this specific fold
    min_val_mse = fold_df['Val_MSE'].min()
    best_epoch_idx = fold_df['Val_MSE'].idxmin()
    min_epoch = fold_df.loc[best_epoch_idx, 'Epoch']
    
    ax.axvline(min_epoch, color='forestgreen', linestyle='--', alpha=0.7, 
               label=f'Best Fold Epoch: {min_epoch}')
    
    ax.set_title(f'Fold {fold} | Min Val MSE: {min_val_mse:.4f}', fontweight='bold')
    ax.set_ylabel('MSE Loss')
    ax.legend(loc='upper right')
    ax.grid(True, which='both', linestyle='--', alpha=0.4)

plt.xlabel('Epoch')
plt.tight_layout()
plt.show()

# %%
# Group by Epoch to find the average behavior across all 5 folds
mean_df = df.groupby('Epoch').agg({
    'Train_MSE': ['mean', 'std'],
    'Val_MSE': ['mean', 'std']
})

# Flatten multi-index columns for easier plotting
mean_df.columns = ['_'.join(col).strip() for col in mean_df.columns.values]

plt.figure(figsize=(12, 6))
epochs = mean_df.index
train_m, train_s = mean_df['Train_MSE_mean'], mean_df['Train_MSE_std']
val_m, val_s = mean_df['Val_MSE_mean'], mean_df['Val_MSE_std']

# Plotting Mean with Standard Deviation Shading
plt.plot(epochs, train_m, label='Mean Train MSE', color='blue', alpha=0.8)
plt.fill_between(epochs, train_m - train_s, train_m + train_s, alpha=0.15, color='blue')

plt.plot(epochs, val_m, label='Mean Val MSE', color='red', linewidth=2)
plt.fill_between(epochs, val_m - val_s, val_m + val_s, alpha=0.15, color='red')

# Find the point of best average convergence
min_avg_val_mse = val_m.min()
best_avg_epoch = val_m.idxmin()

plt.axvline(best_avg_epoch, color='green', linestyle='-', linewidth=1.5,
            label=f'Best Avg Epoch: {best_avg_epoch}')

plt.yscale('log') # Log scale helps visualize convergence at low loss values
plt.title(f'Average Convergence: Trial Total Score Prediction\nBest Avg Epoch: {best_avg_epoch} (MSE: {min_avg_val_mse:.4f})')
plt.ylabel('MSE Loss (Log Scale)')
plt.xlabel('Epoch')
plt.legend()
plt.grid(True, which='both', linestyle='--', alpha=0.3)
plt.show()

print(f"Convergence Note: The model stabilizes at epoch {best_avg_epoch}.")
# Out:
# Convergence Note: The model stabilizes at epoch 95.

# %%
# Extract metrics at the identified best average epoch
best_epoch_data = df[df['Epoch'] == best_avg_epoch]

summary_stats = best_epoch_data[METRIC_COLS].agg(['mean', 'std']).T
summary_stats.columns = ['Mean', 'Std Dev']

print(f"--- Final Metrics at Best Average Epoch ({best_avg_epoch}) ---")
# Using style.format for Jupyter or a standard print for scripts
try:
    from IPython.display import display
    display(summary_stats.style.format("{:.4f}").background_gradient(cmap='Greens', axis=0))
except ImportError:
    print(summary_stats.round(4))

# Final takeaway: R-Squared interpretation
avg_r2 = summary_stats.loc['Val_R2', 'Mean']
print(f"\nFinal Interpretation: Your model explains {avg_r2*100:.1f}% of the variance in total scores.")
# Out:
# --- Final Metrics at Best Average Epoch (95) ---
# <style type="text/css">
# #T_010e1_row0_col0 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_010e1_row0_col1, #T_010e1_row2_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_010e1_row1_col0, #T_010e1_row1_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_010e1_row2_col0 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_010e1_row3_col0 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_010e1_row3_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_010e1_row4_col0, #T_010e1_row4_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_010e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_010e1_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_010e1_level0_col1" class="col_heading level0 col1" >Std Dev</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_010e1_level0_row0" class="row_heading level0 row0" >Train_MSE</th>
#       <td id="T_010e1_row0_col0" class="data row0 col0" >4.4220</td>
#       <td id="T_010e1_row0_col1" class="data row0 col1" >0.2496</td>
#     </tr>
#     <tr>
#       <th id="T_010e1_level0_row1" class="row_heading level0 row1" >Val_MSE</th>
#       <td id="T_010e1_row1_col0" class="data row1 col0" >12.6331</td>
#       <td id="T_010e1_row1_col1" class="data row1 col1" >1.7698</td>
#     </tr>
#     <tr>
#       <th id="T_010e1_level0_row2" class="row_heading level0 row2" >Val_RMSE</th>
#       <td id="T_010e1_row2_col0" class="data row2 col0" >3.5470</td>
#       <td id="T_010e1_row2_col1" class="data row2 col1" >0.2551</td>
#     </tr>
#     <tr>
#       <th id="T_010e1_level0_row3" class="row_heading level0 row3" >Val_MAE</th>
#       <td id="T_010e1_row3_col0" class="data row3 col0" >2.5842</td>
#       <td id="T_010e1_row3_col1" class="data row3 col1" >0.1987</td>
#     </tr>
#     <tr>
#       <th id="T_010e1_level0_row4" class="row_heading level0 row4" >Val_R2</th>
#       <td id="T_010e1_row4_col0" class="data row4 col0" >0.7455</td>
#       <td id="T_010e1_row4_col1" class="data row4 col1" >0.0241</td>
#     </tr>
#   </tbody>
# </table>
# Final Interpretation: Your model explains 74.6% of the variance in total scores.
